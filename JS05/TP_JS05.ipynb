# %% [markdown]
# ## Langkah 13: Clustering dengan HDBSCAN pada Dataset Nyata (Iris)

# %%
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# Muat dataset Iris
iris = load_iris()
X_iris = iris.data
y_iris = iris.target
target_names = iris.target_names

# Lakukan reduksi dimensi menggunakan PCA untuk visualisasi
pca = PCA(n_components=2)
X_iris_pca = pca.fit_transform(X_iris)

# Lakukan clustering dengan HDBSCAN
hdbscan_iris = hdbscan.HDBSCAN(min_cluster_size=5).fit(X_iris_pca)
labels_iris = hdbscan_iris.labels_

# Laporkan hasil
n_clusters_iris = len(set(labels_iris)) - (1 if -1 in labels_iris else 0)
n_noise_iris = list(labels_iris).count(-1)

print(f"Jumlah cluster yang terbentuk: {n_clusters_iris}")
print(f"Banyaknya noise: {n_noise_iris}")

# Visualisasi hasil clustering
fig, ax = plt.subplots(figsize=(10, 6))
plot(X_iris_pca, labels_iris, ax=ax)
ax.set_title("Hasil Clustering HDBSCAN pada Dataset Iris (PCA)")
plt.show()

# Visualisasi label asli
fig, ax = plt.subplots(figsize=(10, 6))
plot(X_iris_pca, y_iris, ground_truth=True, ax=ax)
ax.set_title("Label Asli Dataset Iris (PCA)")
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/deprecation.py:151: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# Jumlah cluster yang terbentuk: 2
# Banyaknya noise: 0
