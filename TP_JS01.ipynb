# %% [markdown]
# <a href="https://colab.research.google.com/github/petrusthelastking/2341720227_ML_2025/blob/main/TP_JS01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 3. Import pandas dan load CSV
import pandas as pd
from IPython.display import display, HTML

# Path ke file CSV
path = '/content/drive/MyDrive/Machine Learning/data-30-mahasiswa.csv'

# Baca CSV ke DataFrame
df = pd.read_csv(path)

display(df)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                    NAMA LENGKAP JENIS KELAMIN      KOTA ASAL  \
# 0                ADITYA ATADEWA     Laki-laki    Kab. Blitar
# 1            AFIFAH KHOIRUNNISA     Perempuan        Nganjuk
# 2       AFRIZAL QURRATUL FAIZIN     Laki-laki         Malang
# 3            AHMAD NAUFAL ILHAM     Laki-Laki         Malang
# 4   ANYA CALLISSTA CHRISWANTARI     Perempuan    Kota Madiun
# 5       ARIL IBBET ARDANA PUTRA     Laki-laki     Banyuwangi
# 6                ARYO ADI PUTRO     Laki-Laki         Jember
# 7      CAKRA WANGSA MAY AHMAD W     Laki-Laki         Blitar
# 8            CHIKO ABILLA BASYA     Laki-laki      Mojokerto
# 9         DAMAR GALIH FITRIANTO   Laki - Laki         Malang
# 10              DIANA RAHMAWATI     Perempuan         Malang
# 11          HAMDAN AZIZUL HAKIM     Laki-Laki         Malang
# ...
